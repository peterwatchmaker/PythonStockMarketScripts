# %%
import pandas_datareader.data as web
import datetime
import pandas as pd

# %%
start = datetime.datetime(2022,8,1)
end = datetime.datetime.today()

# %%
sample = web.DataReader('MTB','yahoo',start,end)
sample.head()

##Are high low changing during day?
##dividends = web.DataReader('E', 'yahoo-dividends', start, end)
##dividends
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2022-08-01  177.350006  174.610001  176.639999  176.089996  1154600
# 2022-08-02  176.100006  173.399994  176.000000  173.809998   958900
#
#              Adj Close
# Date
# 2022-08-01  176.089996
# 2022-08-02  173.809998

# %%
import pandas as pd
from yahoo_fin import stock_info as si

# %%
import matplotlib.pyplot as plt
sample['Close'].plot()
plt.show()

# %%
import yfinance as yf
import pendulum
import matplotlib.pyplot as plt
price_history = yf.Ticker('ETRN').history(period='1d', # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
                                   interval='1m', # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
                                   actions=False)
time_series = list(price_history['Open'])
dt_list = [pendulum.parse(str(dt)).float_timestamp for dt in list(price_history.index)]
plt.style.use('dark_background')
plt.plot(dt_list, time_series, linewidth=2)

# %%
import yfinance as yf
import pendulum
import matplotlib.pyplot as plt
price_history = yf.Ticker('ETRN').history(period='1d', # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
                                   interval='5m', # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
                                   actions=False)
price_history.tail
# Out:
# <bound method NDFrame.tail of                             Open   High     Low   Close  Volume
# Datetime
# 2022-08-04 09:30:00-04:00  8.660  8.710  8.6300  8.6400   74716
# 2022-08-04 09:35:00-04:00  8.640  8.650  8.5650  8.5650   33023
# 2022-08-04 09:40:00-04:00  8.565  8.585  8.5300  8.5301   53691
# 2022-08-04 09:45:00-04:00  8.525  8.630  8.5099  8.6150   41946
# 2022-08-04 09:50:00-04:00  8.610  8.620  8.5250  8.5500   52419
# ...                          ...    ...     ...     ...     ...
# 2022-08-04 15:40:00-04:00  8.465  8.490  8.4600  8.4850   95263
# 2022-08-04 15:45:00-04:00  8.485  8.490  8.4300  8.4450  192703
# 2022-08-04 15:50:00-04:00  8.450  8.470  8.4400  8.4700  132399
# 2022-08-04 15:55:00-04:00  8.465  8.470  8.4000  8.4400  653355
# 2022-08-04 16:00:00-04:00  8.440  8.440  8.4400  8.4400       0
#
# [79 rows x 5 columns]>

# %%
price_history.tail()
# Out:
#                             Open   High    Low   Close  Volume
# Datetime
# 2022-08-01 15:56:00-04:00  7.810  7.820  7.805  7.8113   65546
# 2022-08-01 15:57:00-04:00  7.810  7.815  7.810  7.8150   36016
# 2022-08-01 15:58:00-04:00  7.815  7.840  7.810  7.8400  136368
# 2022-08-01 15:59:00-04:00  7.840  7.860  7.830  7.8400  164500
# 2022-08-01 16:00:00-04:00  7.830  7.830  7.830  7.8300       0

# %%
import yfinance as yf
stock_info = yf.Ticker('HLN').info
# stock_info.keys() for other properties you can explore
market_price = stock_info['regularMarketPrice']
previous_close_price = stock_info['regularMarketPreviousClose']
print('market price ', market_price)
print('previous close price ', previous_close_price)
# Out:
# market price  7.285
# previous close price  7.49

# %%
stock_info = yf.Ticker('HLN').info
print(bcolors.OKBLUE+"GENERAL INFO"+bcolors.ENDC)
print("shortName: "+stock_info['shortName'])
print("symbol: "+stock_info['symbol'])
print("industry: "+stock_info['industry'])
print("website: "+stock_info['website'])
print("BusinessSummary: "+stock_info['longBusinessSummary'])
print(bcolors.OKBLUE+"PRICE INFO"+bcolors.ENDC)
print("targetLowPrice: "+ str(stock_info['targetLowPrice']))
stock_info.keys()
# Out:
# GENERAL INFO
# shortName: Haleon plc
# symbol: HLN
# industry: Drug Manufacturers—Specialty & Generic
# website: https://www.haleon.com
# BusinessSummary: Haleon plc engages in the research and development, manufacture, and sale of various consumer healthcare products in North America, Europe, the Middle East, Africa, Latin America, and the Asia Pacific. The company provides therapeutic oral health, pain relief, respiratory health, digestive health, and other products, as well as vitamins, minerals, and supplements. Its portfolio of brands include Panadol, Voltaren, Advil, Otrivin, Theraflu, Sensodyne, Polident, parodontax, and Centrum. The company was formerly known as DRVW 2022 plc and changed its name to Haleon plc in February 2022. Haleon plc was incorporated in 2021 and is headquartered in Brentford, the United Kingdom.
# PRICE INFO
# targetLowPrice: None
# ...

# %%
#from time import time
stock_info = yf.Ticker('ETRN').info
pricekeys = ['regularMarketPrice','preMarketPrice','priceToBook', 'priceHint', 'previousClose','regularMarketOpen','twoHundredDayAverage','fiftyDayAverage','regularMarketDayHigh','navPrice','regularMarketPreviousClose','open','algorithm','regularMarketDayLow','lastMarket','strikePrice','dayLow','dayHigh','fiftyTwoWeekHigh','fiftyTwoWeekLow',]
for key in pricekeys:
    print(key+": "+str(stock_info.get(key)))



#datetime.datetime.fromtimestamp(stock_info).date().isoformat()
# Out:
# regularMarketPrice: 7.83
# preMarketPrice: 7.66
# priceToBook: 2.1841004
# priceHint: 2
# previousClose: 7.85
# regularMarketOpen: 7.73
# twoHundredDayAverage: 8.5217
# regularMarketDayHigh: 7.95
# navPrice: None
# regularMarketPreviousClose: 7.85
# open: 7.73
# algorithm: None
# regularMarketDayLow: 7.595
# lastMarket: None
# strikePrice: None
# dayLow: 7.595
# dayHigh: 7.95
# fiftyTwoWeekHigh: 11.52
# fiftyTwoWeekLow: 5.87

# %%
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
print(bcolors.OKBLUE + "Warning: No active frommets remain. Continue?")

# %%
dupa = yf.Ticker('HLN')
dupa.calendar
# Out:
# Empty DataFrame
# Columns: []
# Index: [Earnings Date, Earnings Average, Earnings Low, Earnings High, Revenue Average, Revenue Low, Revenue High]

# %%
dupa.earnings_history
#jesli dzisiaj

# %%
#dupa.quarterly_balance_sheet
#dupa.recommendations
#dupa.news
dupa.quarterly_balancesheet
#dupa.quarterly_cashflow
#dupa.quarterly_earnings
dupa.quarterly_financials.T
#dupa.shares.T
# Out:
#            Research Development Effect Of Accounting Charges  \
#
# 2022-03-31           64000000.0                         None
# 2021-03-31           54000000.0                         None
#
#            Income Before Tax Minority Interest   Net Income  \
#
# 2022-03-31       465000000.0       139000000.0  343000000.0
# 2021-03-31       350000000.0       139000000.0  233000000.0
#
#            Selling General Administrative  Gross Profit         Ebit  \
#
# 2022-03-31                   1086000000.0  1613000000.0  466000000.0
# 2021-03-31                   1009000000.0  1402000000.0  348000000.0
#
#            Operating Income Other Operating Expenses  ... Non Recurring  \
#                                                       ...
# 2022-03-31      466000000.0               -3000000.0  ...          None
# 2021-03-31      348000000.0               -9000000.0  ...          None
#
#            Other Items Income Tax Expense Total Revenue  \
#
# ...

# %%
calendar = dupa.get_calendar()
for i in range(calendar.columns.stop):
    print(calendar[i][0])

calendar
# Out:
# Empty DataFrame
# Columns: []
# Index: [Earnings Date, Earnings Average, Earnings Low, Earnings High, Revenue Average, Revenue Low, Revenue High]

# %%
import pandas as pd
from yahoo_fin import stock_info as si

df1 = pd.DataFrame( si.tickers_sp500() )
df2 = pd.DataFrame( si.tickers_nasdaq() )
df3 = pd.DataFrame( si.tickers_dow() )
df4 = pd.DataFrame( si.tickers_other() )

sym1 = set( symbol for symbol in df1[0].values.tolist() )
sym2 = set( symbol for symbol in df2[0].values.tolist() )
sym3 = set( symbol for symbol in df3[0].values.tolist() )
sym4 = set( symbol for symbol in df4[0].values.tolist() )

symbols = set.union( sym1, sym2, sym3, sym4 )
my_list = ['W', 'R', 'P', 'Q']
del_set = set()
sav_set = set()
for symbol in symbols:
    if len( symbol ) > 4 and symbol[-1] in my_list:
        del_set.add( symbol )
    else:
        sav_set.add( symbol )

print( f'Removed {len( del_set )} unqualified stock symbols...' )
print( f'There are {len( sav_set )} qualified stock symbols...' )
# Out:
# Removed 1152 unqualified stock symbols...
# There are 11044 qualified stock symbols...

# %%
def get_exdividend(i):
    stock_info = yf.Ticker(i).info
    if 'exDividendDate' in stock_info.keys():
        #print("found exdividend key")
        if stock_info['exDividendDate'] is not None:
            #print('exdividend is not none')
            if datetime.datetime.fromtimestamp(stock_info['exDividendDate']).date() >= datetime.datetime.today().date():
                #print("exdividend day not in past")
                #print(i+stock_info['exDividendDate'])
                date = datetime.datetime.fromtimestamp(stock_info['exDividendDate'])
                date = date.date().isoformat()
                print(i+" exdividend: "+date)
                return date

# %%
get_exdividend("AMP")
# Out:
# AMP exdividend: 2022-08-05
# '2022-08-05'

# %%
from operator import contains
for i in sav_set:
  if contains(i,'$'):
      i  = (i.split(sep="$"))[0]
  if contains(i,'.U'):
      i  = (i.split(sep="."))[0]
  
  stock_info = yf.Ticker(i).info
  #stock_info.dividends
  #dividend = dupa.info['exDividendDate']
  #date = datetime.datetime.fromtimestamp(dividend)
  #date = date.date().isoformat()
  #date
  stock_info['exDividendDate']


    #print("check on symbol:"+i)
    #str = stock_info.get_dividends()
    #if len(str) > 3:
      #print("dividents found: "+i)
      #last5 = stock_info.dividends
      #int = last5.keys()[4].value
      #int = int/1000000000
  #type(int)
      #date = datetime.datetime.fromtimestamp(int)
      #print(i,date.date())
      #print(datetime.datetime.today())
      #if date.date() > datetime.datetime.today().date():
      #  print(i,date)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 22 in <cell line: 2>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000017untitled?line=7'>8</a> stock_info = yf.Ticker(i).info
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000017untitled?line=8'>9</a> #stock_info.dividends
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000017untitled?line=9'>10</a> #dividend = dupa.info['exDividendDate']
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000017untitled?line=10'>11</a> #date = datetime.datetime.fromtimestamp(dividend)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000017untitled?line=11'>12</a> #date = date.date().isoformat()
# ...

# %%
#from operator import contains, eq
#i = 'ETRN'
#stock_info = yf.Ticker(i)
from operator import contains


for i in sav_set:
    if contains(i,'$'):
        i  = (i.split(sep="$"))[0]
        print(i)
#contains(stock_info.dividends.pop,str)
#time.ctime(int)
# Out:
# MTB
# NMK
# ET
# DS
# YCBD
# BAC
# CODI
# TY
# KEY
# RC
# WBS
# PEB
# ABR
# NYCB
# CIM
# TNP
# TNP
# RJF
# NS
# BRG
# GLP
# GPMT
# WRB
# STAR
# SHO
# DS
# AEL
# ASB
# CDR
# ACR
# PSA
# SCE
# DLR
# CHMI
# PBI
# BEP
# PCG
# TWO
# ALIN
# CUBI
# NLY
# CFG
# WFC
# SCE
# PCG
# DRH
# RNR
# NEE
# TFC
# RC
# TDS
# PRE
# WCC
# PRIF
# JPM
# JPM
# AHL
# BAC
# SI
# ATCO
# MS
# DCP
# OPP
# MH
# IVR
# ETI
# MET
# PCG
# TRTN
# GS
# MS
# GAB
# PW
# LXP
# NGL
# GS
# GNL
# ALL
# BML
# AAIC
# FHN
# PSA
# AAM
# LFT
# INN
# GDL
# WRB
# SF
# MITT
# SPE
# NEE
# FRC
# TGH
# GSL
# INSW
# STAR
# PEI
# PSA
# DBRG
# PCG
# FRC
# WFC
# ATH
# AGM
# SEAL
# VNO
# CTA
# ALL
# PRIF
# AIG
# CSR
# ATCO
# PMT
# CHMI
# PSA
# INN
# ALIN
# TRTN
# GS
# AL
# ARR
# UBP
# TDS
# BML
# RMPL
# NS
# FHN
# HIG
# FRC
# OAK
# NM
# AGM
# PRIF
# FRT
# CORR
# HWM
# ALTG
# PCG
# FNB
# SPNT
# NREF
# NXDT
# ET
# GAM
# PMT
# VNO
# AEL
# NILE
# PEB
# AHL
# FRC
# GGN
# MFA
# RJF
# WFC
# FHN
# BC
# TWO
# NYCB
# BAC
# CLVT
# EPR
# CIO
# T
# PSEC
# ...

# %%
import yfinance as yf
import mplfinance as mpf
import pprint


def plotprices(ticker:str,interval:str,period:str):
    #ticker = "hln"
    #interval = "1h" # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
    #period = "1y" # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
    yticker = yf.Ticker(ticker)
    df = yticker.history(period=period,interval=interval) # max, 1y, 3mo, etc

    mpf.plot(df, type='candle', style='charles', volume=True,title="{} - period={} - interval={}".format(ticker, period, interval))

plotprices("hln",'15m','5d')
plotprices("hln",'1h','3mo')
